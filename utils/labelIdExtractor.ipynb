# %%
import os
import numpy as np
from PIL import Image
from cityscapesscripts.helpers.labels import labels

# %%
COLOR_TO_TRAINID = {label.color: label.trainId for label in labels if label.trainId != 255 and label.trainId != -1}

# %%
print(COLOR_TO_TRAINID)
# Out:
# {(128, 64, 128): 0, (244, 35, 232): 1, (70, 70, 70): 2, (102, 102, 156): 3, (190, 153, 153): 4, (153, 153, 153): 5, (250, 170, 30): 6, (220, 220, 0): 7, (107, 142, 35): 8, (152, 251, 152): 9, (70, 130, 180): 10, (220, 20, 60): 11, (255, 0, 0): 12, (0, 0, 142): 13, (0, 0, 70): 14, (0, 60, 100): 15, (0, 80, 100): 16, (0, 0, 230): 17, (119, 11, 32): 18}

# %%
# Mappa colore RGB → trainId
DEFAULT_TRAINID = 255  # per classi non definite

def rgb_mask_to_trainId(img: Image.Image) -> Image.Image:
    arr = np.array(img)
    h, w, _ = arr.shape
    train_id_mask = np.ones((h, w), dtype=np.uint8) * DEFAULT_TRAINID

    for color, train_id in COLOR_TO_TRAINID.items():
        matches = np.all(arr == color, axis=-1)
        print(f"Found {np.sum(matches)} pixels for color {color} with train_id {train_id}")
        train_id_mask[matches] = train_id

    return Image.fromarray(train_id_mask)

# %%
in_dir = "input_dir_path"  
out_dir = " output_dir_path"
os.makedirs(out_dir, exist_ok=True)

for filename in os.listdir(in_dir):
    if filename.endswith(".png"):
        path = os.path.join(in_dir, filename)
        img = Image.open(path).convert("RGB")
        mask = rgb_mask_to_trainId(img)
        mask.save(os.path.join(out_dir, filename.replace(".png", "_trainId.png")))
# Out:
# Found 182664 pixels for color (128, 64, 128) with train_id 0
# Found 31366 pixels for color (244, 35, 232) with train_id 1
# Found 67488 pixels for color (70, 70, 70) with train_id 2
# Found 14232 pixels for color (102, 102, 156) with train_id 3
# Found 8239 pixels for color (190, 153, 153) with train_id 4
# Found 6609 pixels for color (153, 153, 153) with train_id 5
# Found 389 pixels for color (250, 170, 30) with train_id 6
# Found 922 pixels for color (220, 220, 0) with train_id 7
# Found 18777 pixels for color (107, 142, 35) with train_id 8
# Found 247 pixels for color (152, 251, 152) with train_id 9
# Found 97695 pixels for color (70, 130, 180) with train_id 10
# Found 140 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 353 pixels for color (0, 0, 142) with train_id 13
# Found 2679 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 203442 pixels for color (128, 64, 128) with train_id 0
# Found 23252 pixels for color (244, 35, 232) with train_id 1
# Found 20899 pixels for color (70, 70, 70) with train_id 2
# Found 730 pixels for color (102, 102, 156) with train_id 3
# Found 2203 pixels for color (190, 153, 153) with train_id 4
# Found 17922 pixels for color (153, 153, 153) with train_id 5
# Found 1034 pixels for color (250, 170, 30) with train_id 6
# Found 1281 pixels for color (220, 220, 0) with train_id 7
# Found 19089 pixels for color (107, 142, 35) with train_id 8
# Found 613 pixels for color (152, 251, 152) with train_id 9
# Found 130019 pixels for color (70, 130, 180) with train_id 10
# Found 180 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 5484 pixels for color (0, 0, 142) with train_id 13
# Found 4708 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 195271 pixels for color (128, 64, 128) with train_id 0
# Found 18722 pixels for color (244, 35, 232) with train_id 1
# Found 84477 pixels for color (70, 70, 70) with train_id 2
# Found 1248 pixels for color (102, 102, 156) with train_id 3
# Found 2899 pixels for color (190, 153, 153) with train_id 4
# Found 8770 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 10061 pixels for color (107, 142, 35) with train_id 8
# Found 26131 pixels for color (152, 251, 152) with train_id 9
# Found 88121 pixels for color (70, 130, 180) with train_id 10
# Found 1795 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 1250 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 234090 pixels for color (128, 64, 128) with train_id 0
# Found 9219 pixels for color (244, 35, 232) with train_id 1
# Found 132376 pixels for color (70, 70, 70) with train_id 2
# Found 1519 pixels for color (102, 102, 156) with train_id 3
# Found 11 pixels for color (190, 153, 153) with train_id 4
# Found 9439 pixels for color (153, 153, 153) with train_id 5
# Found 21 pixels for color (250, 170, 30) with train_id 6
# Found 732 pixels for color (220, 220, 0) with train_id 7
# Found 2893 pixels for color (107, 142, 35) with train_id 8
# Found 322 pixels for color (152, 251, 152) with train_id 9
# Found 51379 pixels for color (70, 130, 180) with train_id 10
# Found 4 pixels for color (220, 20, 60) with train_id 11
# Found 405 pixels for color (255, 0, 0) with train_id 12
# Found 1384 pixels for color (0, 0, 142) with train_id 13
# Found 666 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 191 pixels for color (0, 80, 100) with train_id 16
# Found 969 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 202752 pixels for color (128, 64, 128) with train_id 0
# Found 2793 pixels for color (244, 35, 232) with train_id 1
# Found 13342 pixels for color (70, 70, 70) with train_id 2
# Found 13 pixels for color (102, 102, 156) with train_id 3
# Found 356 pixels for color (190, 153, 153) with train_id 4
# Found 3511 pixels for color (153, 153, 153) with train_id 5
# Found 398 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 1346 pixels for color (107, 142, 35) with train_id 8
# Found 256 pixels for color (152, 251, 152) with train_id 9
# Found 86432 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 0 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 136294 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 237126 pixels for color (128, 64, 128) with train_id 0
# Found 15636 pixels for color (244, 35, 232) with train_id 1
# Found 37428 pixels for color (70, 70, 70) with train_id 2
# Found 13299 pixels for color (102, 102, 156) with train_id 3
# Found 1945 pixels for color (190, 153, 153) with train_id 4
# Found 11051 pixels for color (153, 153, 153) with train_id 5
# Found 1966 pixels for color (250, 170, 30) with train_id 6
# Found 3634 pixels for color (220, 220, 0) with train_id 7
# Found 2497 pixels for color (107, 142, 35) with train_id 8
# Found 755 pixels for color (152, 251, 152) with train_id 9
# Found 92662 pixels for color (70, 130, 180) with train_id 10
# Found 814 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 5136 pixels for color (0, 0, 142) with train_id 13
# Found 5497 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 257832 pixels for color (128, 64, 128) with train_id 0
# Found 12765 pixels for color (244, 35, 232) with train_id 1
# Found 1841 pixels for color (70, 70, 70) with train_id 2
# Found 40977 pixels for color (102, 102, 156) with train_id 3
# Found 732 pixels for color (190, 153, 153) with train_id 4
# Found 14277 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 8126 pixels for color (220, 220, 0) with train_id 7
# Found 5732 pixels for color (107, 142, 35) with train_id 8
# Found 28 pixels for color (152, 251, 152) with train_id 9
# Found 98450 pixels for color (70, 130, 180) with train_id 10
# Found 3 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3568 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 194315 pixels for color (128, 64, 128) with train_id 0
# Found 27812 pixels for color (244, 35, 232) with train_id 1
# Found 77610 pixels for color (70, 70, 70) with train_id 2
# Found 23728 pixels for color (102, 102, 156) with train_id 3
# Found 58 pixels for color (190, 153, 153) with train_id 4
# Found 3371 pixels for color (153, 153, 153) with train_id 5
# Found 340 pixels for color (250, 170, 30) with train_id 6
# Found 279 pixels for color (220, 220, 0) with train_id 7
# Found 13598 pixels for color (107, 142, 35) with train_id 8
# Found 1633 pixels for color (152, 251, 152) with train_id 9
# Found 91303 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 19428 pixels for color (0, 0, 142) with train_id 13
# Found 11 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 219964 pixels for color (128, 64, 128) with train_id 0
# Found 7001 pixels for color (244, 35, 232) with train_id 1
# Found 3375 pixels for color (70, 70, 70) with train_id 2
# Found 2718 pixels for color (102, 102, 156) with train_id 3
# Found 7964 pixels for color (190, 153, 153) with train_id 4
# Found 7926 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 56837 pixels for color (107, 142, 35) with train_id 8
# Found 43543 pixels for color (152, 251, 152) with train_id 9
# Found 54065 pixels for color (70, 130, 180) with train_id 10
# Found 110 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 25000 pixels for color (0, 0, 142) with train_id 13
# Found 537 pixels for color (0, 0, 70) with train_id 14
# Found 229 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 180345 pixels for color (128, 64, 128) with train_id 0
# Found 13749 pixels for color (244, 35, 232) with train_id 1
# Found 47860 pixels for color (70, 70, 70) with train_id 2
# Found 3043 pixels for color (102, 102, 156) with train_id 3
# Found 45203 pixels for color (190, 153, 153) with train_id 4
# Found 6012 pixels for color (153, 153, 153) with train_id 5
# Found 386 pixels for color (250, 170, 30) with train_id 6
# Found 945 pixels for color (220, 220, 0) with train_id 7
# Found 36464 pixels for color (107, 142, 35) with train_id 8
# Found 887 pixels for color (152, 251, 152) with train_id 9
# Found 65466 pixels for color (70, 130, 180) with train_id 10
# Found 329 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 2981 pixels for color (0, 0, 142) with train_id 13
# Found 2788 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 183587 pixels for color (128, 64, 128) with train_id 0
# Found 24945 pixels for color (244, 35, 232) with train_id 1
# Found 151453 pixels for color (70, 70, 70) with train_id 2
# Found 106 pixels for color (102, 102, 156) with train_id 3
# Found 1661 pixels for color (190, 153, 153) with train_id 4
# Found 8605 pixels for color (153, 153, 153) with train_id 5
# Found 77 pixels for color (250, 170, 30) with train_id 6
# Found 55 pixels for color (220, 220, 0) with train_id 7
# Found 3434 pixels for color (107, 142, 35) with train_id 8
# Found 403 pixels for color (152, 251, 152) with train_id 9
# Found 49471 pixels for color (70, 130, 180) with train_id 10
# Found 5078 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3469 pixels for color (0, 0, 142) with train_id 13
# Found 2325 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 237337 pixels for color (128, 64, 128) with train_id 0
# Found 11815 pixels for color (244, 35, 232) with train_id 1
# Found 94422 pixels for color (70, 70, 70) with train_id 2
# Found 4370 pixels for color (102, 102, 156) with train_id 3
# Found 6762 pixels for color (190, 153, 153) with train_id 4
# Found 4245 pixels for color (153, 153, 153) with train_id 5
# Found 2060 pixels for color (250, 170, 30) with train_id 6
# Found 2 pixels for color (220, 220, 0) with train_id 7
# Found 27819 pixels for color (107, 142, 35) with train_id 8
# Found 4836 pixels for color (152, 251, 152) with train_id 9
# Found 49114 pixels for color (70, 130, 180) with train_id 10
# Found 438 pixels for color (220, 20, 60) with train_id 11
# Found 241 pixels for color (255, 0, 0) with train_id 12
# Found 2608 pixels for color (0, 0, 142) with train_id 13
# Found 91 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 361 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 195436 pixels for color (128, 64, 128) with train_id 0
# Found 6577 pixels for color (244, 35, 232) with train_id 1
# Found 10557 pixels for color (70, 70, 70) with train_id 2
# Found 30 pixels for color (102, 102, 156) with train_id 3
# Found 46 pixels for color (190, 153, 153) with train_id 4
# Found 2515 pixels for color (153, 153, 153) with train_id 5
# Found 43 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 39489 pixels for color (107, 142, 35) with train_id 8
# Found 36997 pixels for color (152, 251, 152) with train_id 9
# Found 89603 pixels for color (70, 130, 180) with train_id 10
# Found 129 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 47892 pixels for color (0, 0, 142) with train_id 13
# Found 4272 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 147106 pixels for color (128, 64, 128) with train_id 0
# Found 13306 pixels for color (244, 35, 232) with train_id 1
# Found 101045 pixels for color (70, 70, 70) with train_id 2
# Found 503 pixels for color (102, 102, 156) with train_id 3
# Found 510 pixels for color (190, 153, 153) with train_id 4
# Found 2337 pixels for color (153, 153, 153) with train_id 5
# Found 75 pixels for color (250, 170, 30) with train_id 6
# Found 39 pixels for color (220, 220, 0) with train_id 7
# Found 60132 pixels for color (107, 142, 35) with train_id 8
# Found 3720 pixels for color (152, 251, 152) with train_id 9
# Found 21336 pixels for color (70, 130, 180) with train_id 10
# Found 289 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 78136 pixels for color (0, 0, 142) with train_id 13
# Found 919 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 222403 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 10309 pixels for color (70, 70, 70) with train_id 2
# Found 50519 pixels for color (102, 102, 156) with train_id 3
# Found 21 pixels for color (190, 153, 153) with train_id 4
# Found 2172 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 806 pixels for color (220, 220, 0) with train_id 7
# Found 35527 pixels for color (107, 142, 35) with train_id 8
# Found 35 pixels for color (152, 251, 152) with train_id 9
# Found 124528 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 2853 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 127513 pixels for color (128, 64, 128) with train_id 0
# Found 33541 pixels for color (244, 35, 232) with train_id 1
# Found 107566 pixels for color (70, 70, 70) with train_id 2
# Found 4359 pixels for color (102, 102, 156) with train_id 3
# Found 2392 pixels for color (190, 153, 153) with train_id 4
# Found 3655 pixels for color (153, 153, 153) with train_id 5
# Found 400 pixels for color (250, 170, 30) with train_id 6
# Found 306 pixels for color (220, 220, 0) with train_id 7
# Found 53968 pixels for color (107, 142, 35) with train_id 8
# Found 714 pixels for color (152, 251, 152) with train_id 9
# Found 39284 pixels for color (70, 130, 180) with train_id 10
# Found 1792 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 51397 pixels for color (0, 0, 142) with train_id 13
# Found 222 pixels for color (0, 0, 70) with train_id 14
# Found 367 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 240659 pixels for color (128, 64, 128) with train_id 0
# Found 9571 pixels for color (244, 35, 232) with train_id 1
# Found 21619 pixels for color (70, 70, 70) with train_id 2
# Found 24571 pixels for color (102, 102, 156) with train_id 3
# Found 386 pixels for color (190, 153, 153) with train_id 4
# Found 3274 pixels for color (153, 153, 153) with train_id 5
# Found 130 pixels for color (250, 170, 30) with train_id 6
# Found 156 pixels for color (220, 220, 0) with train_id 7
# Found 22060 pixels for color (107, 142, 35) with train_id 8
# Found 1708 pixels for color (152, 251, 152) with train_id 9
# Found 133705 pixels for color (70, 130, 180) with train_id 10
# Found 14 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 1349 pixels for color (0, 0, 142) with train_id 13
# Found 67 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 208331 pixels for color (128, 64, 128) with train_id 0
# Found 8095 pixels for color (244, 35, 232) with train_id 1
# Found 24552 pixels for color (70, 70, 70) with train_id 2
# Found 11032 pixels for color (102, 102, 156) with train_id 3
# Found 21087 pixels for color (190, 153, 153) with train_id 4
# Found 4180 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 1104 pixels for color (220, 220, 0) with train_id 7
# Found 46008 pixels for color (107, 142, 35) with train_id 8
# Found 18688 pixels for color (152, 251, 152) with train_id 9
# Found 91510 pixels for color (70, 130, 180) with train_id 10
# Found 3 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 0 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 176733 pixels for color (128, 64, 128) with train_id 0
# Found 19934 pixels for color (244, 35, 232) with train_id 1
# Found 54651 pixels for color (70, 70, 70) with train_id 2
# Found 4449 pixels for color (102, 102, 156) with train_id 3
# Found 180 pixels for color (190, 153, 153) with train_id 4
# Found 5010 pixels for color (153, 153, 153) with train_id 5
# Found 436 pixels for color (250, 170, 30) with train_id 6
# Found 5 pixels for color (220, 220, 0) with train_id 7
# Found 99154 pixels for color (107, 142, 35) with train_id 8
# Found 1950 pixels for color (152, 251, 152) with train_id 9
# Found 58255 pixels for color (70, 130, 180) with train_id 10
# Found 898 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 6550 pixels for color (0, 0, 142) with train_id 13
# Found 1930 pixels for color (0, 0, 70) with train_id 14
# Found 134 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 181562 pixels for color (128, 64, 128) with train_id 0
# Found 48745 pixels for color (244, 35, 232) with train_id 1
# Found 63331 pixels for color (70, 70, 70) with train_id 2
# Found 96 pixels for color (102, 102, 156) with train_id 3
# Found 87 pixels for color (190, 153, 153) with train_id 4
# Found 17124 pixels for color (153, 153, 153) with train_id 5
# Found 1061 pixels for color (250, 170, 30) with train_id 6
# Found 1584 pixels for color (220, 220, 0) with train_id 7
# Found 50752 pixels for color (107, 142, 35) with train_id 8
# Found 10657 pixels for color (152, 251, 152) with train_id 9
# Found 42512 pixels for color (70, 130, 180) with train_id 10
# Found 839 pixels for color (220, 20, 60) with train_id 11
# Found 53 pixels for color (255, 0, 0) with train_id 12
# Found 9478 pixels for color (0, 0, 142) with train_id 13
# Found 17 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 4 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 130500 pixels for color (128, 64, 128) with train_id 0
# Found 28663 pixels for color (244, 35, 232) with train_id 1
# Found 40943 pixels for color (70, 70, 70) with train_id 2
# Found 2108 pixels for color (102, 102, 156) with train_id 3
# Found 8 pixels for color (190, 153, 153) with train_id 4
# Found 2531 pixels for color (153, 153, 153) with train_id 5
# Found 1033 pixels for color (250, 170, 30) with train_id 6
# Found 931 pixels for color (220, 220, 0) with train_id 7
# Found 53461 pixels for color (107, 142, 35) with train_id 8
# Found 2492 pixels for color (152, 251, 152) with train_id 9
# Found 35661 pixels for color (70, 130, 180) with train_id 10
# Found 556 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 37699 pixels for color (0, 0, 142) with train_id 13
# Found 96 pixels for color (0, 0, 70) with train_id 14
# Found 95459 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 240386 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 1935 pixels for color (70, 70, 70) with train_id 2
# Found 0 pixels for color (102, 102, 156) with train_id 3
# Found 232 pixels for color (190, 153, 153) with train_id 4
# Found 1072 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 210 pixels for color (220, 220, 0) with train_id 7
# Found 28875 pixels for color (107, 142, 35) with train_id 8
# Found 50837 pixels for color (152, 251, 152) with train_id 9
# Found 119231 pixels for color (70, 130, 180) with train_id 10
# Found 17 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 807 pixels for color (0, 0, 142) with train_id 13
# Found 3698 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 254712 pixels for color (128, 64, 128) with train_id 0
# Found 5428 pixels for color (244, 35, 232) with train_id 1
# Found 46355 pixels for color (70, 70, 70) with train_id 2
# Found 74 pixels for color (102, 102, 156) with train_id 3
# Found 95 pixels for color (190, 153, 153) with train_id 4
# Found 9914 pixels for color (153, 153, 153) with train_id 5
# Found 944 pixels for color (250, 170, 30) with train_id 6
# Found 547 pixels for color (220, 220, 0) with train_id 7
# Found 4176 pixels for color (107, 142, 35) with train_id 8
# Found 951 pixels for color (152, 251, 152) with train_id 9
# Found 97796 pixels for color (70, 130, 180) with train_id 10
# Found 326 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 11930 pixels for color (0, 0, 142) with train_id 13
# Found 40 pixels for color (0, 0, 70) with train_id 14
# Found 10353 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 218894 pixels for color (128, 64, 128) with train_id 0
# Found 13250 pixels for color (244, 35, 232) with train_id 1
# Found 1459 pixels for color (70, 70, 70) with train_id 2
# Found 11776 pixels for color (102, 102, 156) with train_id 3
# Found 3633 pixels for color (190, 153, 153) with train_id 4
# Found 10506 pixels for color (153, 153, 153) with train_id 5
# Found 1713 pixels for color (250, 170, 30) with train_id 6
# Found 452 pixels for color (220, 220, 0) with train_id 7
# Found 33667 pixels for color (107, 142, 35) with train_id 8
# Found 1145 pixels for color (152, 251, 152) with train_id 9
# Found 56456 pixels for color (70, 130, 180) with train_id 10
# Found 1134 pixels for color (220, 20, 60) with train_id 11
# Found 1150 pixels for color (255, 0, 0) with train_id 12
# Found 37956 pixels for color (0, 0, 142) with train_id 13
# Found 87 pixels for color (0, 0, 70) with train_id 14
# Found 638 pixels for color (0, 60, 100) with train_id 15
# Found 174 pixels for color (0, 80, 100) with train_id 16
# Found 1233 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 235690 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 2004 pixels for color (70, 70, 70) with train_id 2
# Found 0 pixels for color (102, 102, 156) with train_id 3
# Found 6255 pixels for color (190, 153, 153) with train_id 4
# Found 2415 pixels for color (153, 153, 153) with train_id 5
# Found 51 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 46033 pixels for color (107, 142, 35) with train_id 8
# Found 6626 pixels for color (152, 251, 152) with train_id 9
# Found 139964 pixels for color (70, 130, 180) with train_id 10
# Found 2 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 8002 pixels for color (0, 0, 142) with train_id 13
# Found 58 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 188166 pixels for color (128, 64, 128) with train_id 0
# Found 8647 pixels for color (244, 35, 232) with train_id 1
# Found 49969 pixels for color (70, 70, 70) with train_id 2
# Found 141 pixels for color (102, 102, 156) with train_id 3
# Found 64 pixels for color (190, 153, 153) with train_id 4
# Found 2078 pixels for color (153, 153, 153) with train_id 5
# Found 89 pixels for color (250, 170, 30) with train_id 6
# Found 67 pixels for color (220, 220, 0) with train_id 7
# Found 79339 pixels for color (107, 142, 35) with train_id 8
# Found 1179 pixels for color (152, 251, 152) with train_id 9
# Found 71464 pixels for color (70, 130, 180) with train_id 10
# Found 1119 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 1471 pixels for color (0, 0, 142) with train_id 13
# Found 18110 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 198997 pixels for color (128, 64, 128) with train_id 0
# Found 15005 pixels for color (244, 35, 232) with train_id 1
# Found 58833 pixels for color (70, 70, 70) with train_id 2
# Found 11254 pixels for color (102, 102, 156) with train_id 3
# Found 4494 pixels for color (190, 153, 153) with train_id 4
# Found 4894 pixels for color (153, 153, 153) with train_id 5
# Found 2027 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 59410 pixels for color (107, 142, 35) with train_id 8
# Found 215 pixels for color (152, 251, 152) with train_id 9
# Found 99262 pixels for color (70, 130, 180) with train_id 10
# Found 276 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 22351 pixels for color (0, 0, 142) with train_id 13
# Found 1380 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 256405 pixels for color (128, 64, 128) with train_id 0
# Found 16840 pixels for color (244, 35, 232) with train_id 1
# Found 21983 pixels for color (70, 70, 70) with train_id 2
# Found 16953 pixels for color (102, 102, 156) with train_id 3
# Found 683 pixels for color (190, 153, 153) with train_id 4
# Found 5390 pixels for color (153, 153, 153) with train_id 5
# Found 129 pixels for color (250, 170, 30) with train_id 6
# Found 38 pixels for color (220, 220, 0) with train_id 7
# Found 2952 pixels for color (107, 142, 35) with train_id 8
# Found 330 pixels for color (152, 251, 152) with train_id 9
# Found 108004 pixels for color (70, 130, 180) with train_id 10
# Found 286 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 602 pixels for color (0, 0, 142) with train_id 13
# Found 49313 pixels for color (0, 0, 70) with train_id 14
# Found 62 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 185408 pixels for color (128, 64, 128) with train_id 0
# Found 2454 pixels for color (244, 35, 232) with train_id 1
# Found 109118 pixels for color (70, 70, 70) with train_id 2
# Found 4708 pixels for color (102, 102, 156) with train_id 3
# Found 134 pixels for color (190, 153, 153) with train_id 4
# Found 4169 pixels for color (153, 153, 153) with train_id 5
# Found 3630 pixels for color (250, 170, 30) with train_id 6
# Found 1395 pixels for color (220, 220, 0) with train_id 7
# Found 29234 pixels for color (107, 142, 35) with train_id 8
# Found 20 pixels for color (152, 251, 152) with train_id 9
# Found 37710 pixels for color (70, 130, 180) with train_id 10
# Found 102 pixels for color (220, 20, 60) with train_id 11
# Found 493 pixels for color (255, 0, 0) with train_id 12
# Found 68820 pixels for color (0, 0, 142) with train_id 13
# Found 696 pixels for color (0, 0, 70) with train_id 14
# Found 78 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 446 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 264440 pixels for color (128, 64, 128) with train_id 0
# Found 4884 pixels for color (244, 35, 232) with train_id 1
# Found 57467 pixels for color (70, 70, 70) with train_id 2
# Found 153 pixels for color (102, 102, 156) with train_id 3
# Found 1396 pixels for color (190, 153, 153) with train_id 4
# Found 14210 pixels for color (153, 153, 153) with train_id 5
# Found 4915 pixels for color (250, 170, 30) with train_id 6
# Found 437 pixels for color (220, 220, 0) with train_id 7
# Found 2206 pixels for color (107, 142, 35) with train_id 8
# Found 238 pixels for color (152, 251, 152) with train_id 9
# Found 81662 pixels for color (70, 130, 180) with train_id 10
# Found 7 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3619 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 51042 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 187340 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 33197 pixels for color (70, 70, 70) with train_id 2
# Found 0 pixels for color (102, 102, 156) with train_id 3
# Found 1 pixels for color (190, 153, 153) with train_id 4
# Found 1687 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 322 pixels for color (220, 220, 0) with train_id 7
# Found 22005 pixels for color (107, 142, 35) with train_id 8
# Found 51673 pixels for color (152, 251, 152) with train_id 9
# Found 90194 pixels for color (70, 130, 180) with train_id 10
# Found 23 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 4401 pixels for color (0, 0, 142) with train_id 13
# Found 958 pixels for color (0, 0, 70) with train_id 14
# Found 92 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 213150 pixels for color (128, 64, 128) with train_id 0
# Found 7577 pixels for color (244, 35, 232) with train_id 1
# Found 28300 pixels for color (70, 70, 70) with train_id 2
# Found 4879 pixels for color (102, 102, 156) with train_id 3
# Found 32 pixels for color (190, 153, 153) with train_id 4
# Found 6272 pixels for color (153, 153, 153) with train_id 5
# Found 88 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 47536 pixels for color (107, 142, 35) with train_id 8
# Found 16094 pixels for color (152, 251, 152) with train_id 9
# Found 109559 pixels for color (70, 130, 180) with train_id 10
# Found 315 pixels for color (220, 20, 60) with train_id 11
# Found 604 pixels for color (255, 0, 0) with train_id 12
# Found 3873 pixels for color (0, 0, 142) with train_id 13
# Found 12 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 195 pixels for color (119, 11, 32) with train_id 18
# Found 185374 pixels for color (128, 64, 128) with train_id 0
# Found 26730 pixels for color (244, 35, 232) with train_id 1
# Found 122295 pixels for color (70, 70, 70) with train_id 2
# Found 1115 pixels for color (102, 102, 156) with train_id 3
# Found 0 pixels for color (190, 153, 153) with train_id 4
# Found 8431 pixels for color (153, 153, 153) with train_id 5
# Found 1482 pixels for color (250, 170, 30) with train_id 6
# Found 70 pixels for color (220, 220, 0) with train_id 7
# Found 36480 pixels for color (107, 142, 35) with train_id 8
# Found 336 pixels for color (152, 251, 152) with train_id 9
# Found 32912 pixels for color (70, 130, 180) with train_id 10
# Found 288 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 10802 pixels for color (0, 0, 142) with train_id 13
# Found 10 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 238782 pixels for color (128, 64, 128) with train_id 0
# Found 7230 pixels for color (244, 35, 232) with train_id 1
# Found 93454 pixels for color (70, 70, 70) with train_id 2
# Found 228 pixels for color (102, 102, 156) with train_id 3
# Found 3084 pixels for color (190, 153, 153) with train_id 4
# Found 11948 pixels for color (153, 153, 153) with train_id 5
# Found 2559 pixels for color (250, 170, 30) with train_id 6
# Found 184 pixels for color (220, 220, 0) with train_id 7
# Found 11586 pixels for color (107, 142, 35) with train_id 8
# Found 821 pixels for color (152, 251, 152) with train_id 9
# Found 78684 pixels for color (70, 130, 180) with train_id 10
# Found 89 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 5402 pixels for color (0, 0, 142) with train_id 13
# Found 1611 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 212034 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 1798 pixels for color (70, 70, 70) with train_id 2
# Found 427 pixels for color (102, 102, 156) with train_id 3
# Found 130 pixels for color (190, 153, 153) with train_id 4
# Found 14653 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 9013 pixels for color (220, 220, 0) with train_id 7
# Found 67345 pixels for color (107, 142, 35) with train_id 8
# Found 58316 pixels for color (152, 251, 152) with train_id 9
# Found 46729 pixels for color (70, 130, 180) with train_id 10
# Found 1 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 1318 pixels for color (0, 0, 142) with train_id 13
# Found 646 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 235321 pixels for color (128, 64, 128) with train_id 0
# Found 3960 pixels for color (244, 35, 232) with train_id 1
# Found 154108 pixels for color (70, 70, 70) with train_id 2
# Found 1534 pixels for color (102, 102, 156) with train_id 3
# Found 0 pixels for color (190, 153, 153) with train_id 4
# Found 1378 pixels for color (153, 153, 153) with train_id 5
# Found 926 pixels for color (250, 170, 30) with train_id 6
# Found 28 pixels for color (220, 220, 0) with train_id 7
# Found 8672 pixels for color (107, 142, 35) with train_id 8
# Found 1143 pixels for color (152, 251, 152) with train_id 9
# Found 15212 pixels for color (70, 130, 180) with train_id 10
# Found 82 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3825 pixels for color (0, 0, 142) with train_id 13
# Found 10912 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 195691 pixels for color (128, 64, 128) with train_id 0
# Found 13783 pixels for color (244, 35, 232) with train_id 1
# Found 59710 pixels for color (70, 70, 70) with train_id 2
# Found 17310 pixels for color (102, 102, 156) with train_id 3
# Found 273 pixels for color (190, 153, 153) with train_id 4
# Found 8996 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 3 pixels for color (220, 220, 0) with train_id 7
# Found 3005 pixels for color (107, 142, 35) with train_id 8
# Found 16041 pixels for color (152, 251, 152) with train_id 9
# Found 62146 pixels for color (70, 130, 180) with train_id 10
# Found 30 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 79 pixels for color (0, 0, 142) with train_id 13
# Found 34 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 231669 pixels for color (128, 64, 128) with train_id 0
# Found 10885 pixels for color (244, 35, 232) with train_id 1
# Found 78067 pixels for color (70, 70, 70) with train_id 2
# Found 1963 pixels for color (102, 102, 156) with train_id 3
# Found 13 pixels for color (190, 153, 153) with train_id 4
# Found 4975 pixels for color (153, 153, 153) with train_id 5
# Found 388 pixels for color (250, 170, 30) with train_id 6
# Found 340 pixels for color (220, 220, 0) with train_id 7
# Found 26885 pixels for color (107, 142, 35) with train_id 8
# Found 3441 pixels for color (152, 251, 152) with train_id 9
# Found 67352 pixels for color (70, 130, 180) with train_id 10
# Found 120 pixels for color (220, 20, 60) with train_id 11
# Found 43 pixels for color (255, 0, 0) with train_id 12
# Found 1574 pixels for color (0, 0, 142) with train_id 13
# Found 3803 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 93 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 196874 pixels for color (128, 64, 128) with train_id 0
# Found 5215 pixels for color (244, 35, 232) with train_id 1
# Found 145106 pixels for color (70, 70, 70) with train_id 2
# Found 0 pixels for color (102, 102, 156) with train_id 3
# Found 2 pixels for color (190, 153, 153) with train_id 4
# Found 4415 pixels for color (153, 153, 153) with train_id 5
# Found 1425 pixels for color (250, 170, 30) with train_id 6
# Found 83 pixels for color (220, 220, 0) with train_id 7
# Found 7518 pixels for color (107, 142, 35) with train_id 8
# Found 6324 pixels for color (152, 251, 152) with train_id 9
# Found 62714 pixels for color (70, 130, 180) with train_id 10
# Found 1222 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3532 pixels for color (0, 0, 142) with train_id 13
# Found 681 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 197601 pixels for color (128, 64, 128) with train_id 0
# Found 27188 pixels for color (244, 35, 232) with train_id 1
# Found 179732 pixels for color (70, 70, 70) with train_id 2
# Found 75 pixels for color (102, 102, 156) with train_id 3
# Found 0 pixels for color (190, 153, 153) with train_id 4
# Found 3446 pixels for color (153, 153, 153) with train_id 5
# Found 339 pixels for color (250, 170, 30) with train_id 6
# Found 84 pixels for color (220, 220, 0) with train_id 7
# Found 3541 pixels for color (107, 142, 35) with train_id 8
# Found 812 pixels for color (152, 251, 152) with train_id 9
# Found 25630 pixels for color (70, 130, 180) with train_id 10
# Found 3071 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 6963 pixels for color (0, 0, 142) with train_id 13
# Found 4865 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 216414 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 82 pixels for color (70, 70, 70) with train_id 2
# Found 20201 pixels for color (102, 102, 156) with train_id 3
# Found 0 pixels for color (190, 153, 153) with train_id 4
# Found 3388 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 24113 pixels for color (107, 142, 35) with train_id 8
# Found 114469 pixels for color (152, 251, 152) with train_id 9
# Found 42545 pixels for color (70, 130, 180) with train_id 10
# Found 12 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 12950 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 171274 pixels for color (128, 64, 128) with train_id 0
# Found 23777 pixels for color (244, 35, 232) with train_id 1
# Found 58976 pixels for color (70, 70, 70) with train_id 2
# Found 3430 pixels for color (102, 102, 156) with train_id 3
# Found 1711 pixels for color (190, 153, 153) with train_id 4
# Found 3885 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 34 pixels for color (220, 220, 0) with train_id 7
# Found 52503 pixels for color (107, 142, 35) with train_id 8
# Found 12849 pixels for color (152, 251, 152) with train_id 9
# Found 92626 pixels for color (70, 130, 180) with train_id 10
# Found 147 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 76 pixels for color (0, 0, 142) with train_id 13
# Found 309 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 201752 pixels for color (128, 64, 128) with train_id 0
# Found 20513 pixels for color (244, 35, 232) with train_id 1
# Found 24375 pixels for color (70, 70, 70) with train_id 2
# Found 8747 pixels for color (102, 102, 156) with train_id 3
# Found 2656 pixels for color (190, 153, 153) with train_id 4
# Found 4334 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 76354 pixels for color (107, 142, 35) with train_id 8
# Found 11183 pixels for color (152, 251, 152) with train_id 9
# Found 80990 pixels for color (70, 130, 180) with train_id 10
# Found 128 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 5738 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 220032 pixels for color (128, 64, 128) with train_id 0
# Found 16149 pixels for color (244, 35, 232) with train_id 1
# Found 37427 pixels for color (70, 70, 70) with train_id 2
# Found 0 pixels for color (102, 102, 156) with train_id 3
# Found 82 pixels for color (190, 153, 153) with train_id 4
# Found 11972 pixels for color (153, 153, 153) with train_id 5
# Found 2553 pixels for color (250, 170, 30) with train_id 6
# Found 436 pixels for color (220, 220, 0) with train_id 7
# Found 33387 pixels for color (107, 142, 35) with train_id 8
# Found 2959 pixels for color (152, 251, 152) with train_id 9
# Found 127509 pixels for color (70, 130, 180) with train_id 10
# Found 31 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 4753 pixels for color (0, 0, 142) with train_id 13
# ...
# Found 28814 pixels for color (107, 142, 35) with train_id 8
# Found 3038 pixels for color (152, 251, 152) with train_id 9
# Found 118656 pixels for color (70, 130, 180) with train_id 10
# Found 1625 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 21721 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 196191 pixels for color (128, 64, 128) with train_id 0
# Found 7868 pixels for color (244, 35, 232) with train_id 1
# Found 16123 pixels for color (70, 70, 70) with train_id 2
# Found 5461 pixels for color (102, 102, 156) with train_id 3
# Found 15915 pixels for color (190, 153, 153) with train_id 4
# Found 4812 pixels for color (153, 153, 153) with train_id 5
# Found 10 pixels for color (250, 170, 30) with train_id 6
# Found 403 pixels for color (220, 220, 0) with train_id 7
# Found 52984 pixels for color (107, 142, 35) with train_id 8
# Found 23338 pixels for color (152, 251, 152) with train_id 9
# Found 110106 pixels for color (70, 130, 180) with train_id 10
# Found 5 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 0 pixels for color (0, 0, 142) with train_id 13
# Found 5 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 189756 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 18884 pixels for color (70, 70, 70) with train_id 2
# Found 74610 pixels for color (102, 102, 156) with train_id 3
# Found 2401 pixels for color (190, 153, 153) with train_id 4
# Found 14636 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 210 pixels for color (220, 220, 0) with train_id 7
# Found 621 pixels for color (107, 142, 35) with train_id 8
# Found 0 pixels for color (152, 251, 152) with train_id 9
# Found 165067 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 0 pixels for color (0, 0, 142) with train_id 13
# Found 170 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 207598 pixels for color (128, 64, 128) with train_id 0
# Found 0 pixels for color (244, 35, 232) with train_id 1
# Found 7381 pixels for color (70, 70, 70) with train_id 2
# Found 37096 pixels for color (102, 102, 156) with train_id 3
# Found 13 pixels for color (190, 153, 153) with train_id 4
# Found 2036 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 538 pixels for color (220, 220, 0) with train_id 7
# Found 31156 pixels for color (107, 142, 35) with train_id 8
# Found 209 pixels for color (152, 251, 152) with train_id 9
# Found 119589 pixels for color (70, 130, 180) with train_id 10
# Found 1 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 41507 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 80688 pixels for color (128, 64, 128) with train_id 0
# Found 11792 pixels for color (244, 35, 232) with train_id 1
# Found 8017 pixels for color (70, 70, 70) with train_id 2
# Found 192449 pixels for color (102, 102, 156) with train_id 3
# Found 0 pixels for color (190, 153, 153) with train_id 4
# Found 8 pixels for color (153, 153, 153) with train_id 5
# Found 0 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 60200 pixels for color (107, 142, 35) with train_id 8
# Found 116 pixels for color (152, 251, 152) with train_id 9
# Found 43557 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 0 pixels for color (0, 0, 142) with train_id 13
# Found 0 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 184800 pixels for color (128, 64, 128) with train_id 0
# Found 16528 pixels for color (244, 35, 232) with train_id 1
# Found 112315 pixels for color (70, 70, 70) with train_id 2
# Found 4280 pixels for color (102, 102, 156) with train_id 3
# Found 683 pixels for color (190, 153, 153) with train_id 4
# Found 2494 pixels for color (153, 153, 153) with train_id 5
# Found 166 pixels for color (250, 170, 30) with train_id 6
# Found 99 pixels for color (220, 220, 0) with train_id 7
# Found 75766 pixels for color (107, 142, 35) with train_id 8
# Found 4647 pixels for color (152, 251, 152) with train_id 9
# Found 14166 pixels for color (70, 130, 180) with train_id 10
# Found 1423 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 11812 pixels for color (0, 0, 142) with train_id 13
# Found 1188 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 227308 pixels for color (128, 64, 128) with train_id 0
# Found 5822 pixels for color (244, 35, 232) with train_id 1
# Found 102664 pixels for color (70, 70, 70) with train_id 2
# Found 2745 pixels for color (102, 102, 156) with train_id 3
# Found 3777 pixels for color (190, 153, 153) with train_id 4
# Found 2435 pixels for color (153, 153, 153) with train_id 5
# Found 972 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 22518 pixels for color (107, 142, 35) with train_id 8
# Found 2000 pixels for color (152, 251, 152) with train_id 9
# Found 56792 pixels for color (70, 130, 180) with train_id 10
# Found 457 pixels for color (220, 20, 60) with train_id 11
# Found 2925 pixels for color (255, 0, 0) with train_id 12
# Found 11324 pixels for color (0, 0, 142) with train_id 13
# Found 144 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 7852 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 225143 pixels for color (128, 64, 128) with train_id 0
# Found 23585 pixels for color (244, 35, 232) with train_id 1
# Found 76994 pixels for color (70, 70, 70) with train_id 2
# Found 1906 pixels for color (102, 102, 156) with train_id 3
# Found 829 pixels for color (190, 153, 153) with train_id 4
# Found 8488 pixels for color (153, 153, 153) with train_id 5
# Found 1816 pixels for color (250, 170, 30) with train_id 6
# Found 212 pixels for color (220, 220, 0) with train_id 7
# Found 21053 pixels for color (107, 142, 35) with train_id 8
# Found 1062 pixels for color (152, 251, 152) with train_id 9
# Found 69751 pixels for color (70, 130, 180) with train_id 10
# Found 268 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 3729 pixels for color (0, 0, 142) with train_id 13
# Found 1437 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 198970 pixels for color (128, 64, 128) with train_id 0
# Found 6166 pixels for color (244, 35, 232) with train_id 1
# Found 93826 pixels for color (70, 70, 70) with train_id 2
# Found 11472 pixels for color (102, 102, 156) with train_id 3
# Found 34 pixels for color (190, 153, 153) with train_id 4
# Found 4263 pixels for color (153, 153, 153) with train_id 5
# Found 999 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 60839 pixels for color (107, 142, 35) with train_id 8
# Found 2221 pixels for color (152, 251, 152) with train_id 9
# Found 46338 pixels for color (70, 130, 180) with train_id 10
# Found 193 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 7470 pixels for color (0, 0, 142) with train_id 13
# Found 377 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 177611 pixels for color (128, 64, 128) with train_id 0
# Found 29330 pixels for color (244, 35, 232) with train_id 1
# Found 103766 pixels for color (70, 70, 70) with train_id 2
# Found 2765 pixels for color (102, 102, 156) with train_id 3
# Found 826 pixels for color (190, 153, 153) with train_id 4
# Found 1938 pixels for color (153, 153, 153) with train_id 5
# Found 50 pixels for color (250, 170, 30) with train_id 6
# Found 0 pixels for color (220, 220, 0) with train_id 7
# Found 29842 pixels for color (107, 142, 35) with train_id 8
# Found 1993 pixels for color (152, 251, 152) with train_id 9
# Found 67576 pixels for color (70, 130, 180) with train_id 10
# Found 108 pixels for color (220, 20, 60) with train_id 11
# Found 9 pixels for color (255, 0, 0) with train_id 12
# Found 7841 pixels for color (0, 0, 142) with train_id 13
# Found 35 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 13 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 220341 pixels for color (128, 64, 128) with train_id 0
# Found 18955 pixels for color (244, 35, 232) with train_id 1
# Found 62272 pixels for color (70, 70, 70) with train_id 2
# Found 17947 pixels for color (102, 102, 156) with train_id 3
# Found 300 pixels for color (190, 153, 153) with train_id 4
# Found 2710 pixels for color (153, 153, 153) with train_id 5
# Found 492 pixels for color (250, 170, 30) with train_id 6
# Found 236 pixels for color (220, 220, 0) with train_id 7
# Found 20926 pixels for color (107, 142, 35) with train_id 8
# Found 2759 pixels for color (152, 251, 152) with train_id 9
# Found 78658 pixels for color (70, 130, 180) with train_id 10
# Found 1246 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 4629 pixels for color (0, 0, 142) with train_id 13
# Found 4015 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 2 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 206519 pixels for color (128, 64, 128) with train_id 0
# Found 14809 pixels for color (244, 35, 232) with train_id 1
# Found 45142 pixels for color (70, 70, 70) with train_id 2
# Found 49797 pixels for color (102, 102, 156) with train_id 3
# Found 720 pixels for color (190, 153, 153) with train_id 4
# Found 5245 pixels for color (153, 153, 153) with train_id 5
# Found 2773 pixels for color (250, 170, 30) with train_id 6
# Found 6 pixels for color (220, 220, 0) with train_id 7
# Found 4758 pixels for color (107, 142, 35) with train_id 8
# Found 6 pixels for color (152, 251, 152) with train_id 9
# Found 4217 pixels for color (70, 130, 180) with train_id 10
# Found 0 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 6107 pixels for color (0, 0, 142) with train_id 13
# Found 99222 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 211349 pixels for color (128, 64, 128) with train_id 0
# Found 29826 pixels for color (244, 35, 232) with train_id 1
# Found 102796 pixels for color (70, 70, 70) with train_id 2
# Found 212 pixels for color (102, 102, 156) with train_id 3
# Found 8 pixels for color (190, 153, 153) with train_id 4
# Found 6698 pixels for color (153, 153, 153) with train_id 5
# Found 3302 pixels for color (250, 170, 30) with train_id 6
# Found 320 pixels for color (220, 220, 0) with train_id 7
# Found 12366 pixels for color (107, 142, 35) with train_id 8
# Found 904 pixels for color (152, 251, 152) with train_id 9
# Found 44275 pixels for color (70, 130, 180) with train_id 10
# Found 96 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 1960 pixels for color (0, 0, 142) with train_id 13
# Found 13802 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 221368 pixels for color (128, 64, 128) with train_id 0
# Found 13479 pixels for color (244, 35, 232) with train_id 1
# Found 15351 pixels for color (70, 70, 70) with train_id 2
# Found 3360 pixels for color (102, 102, 156) with train_id 3
# Found 1342 pixels for color (190, 153, 153) with train_id 4
# Found 2087 pixels for color (153, 153, 153) with train_id 5
# Found 4 pixels for color (250, 170, 30) with train_id 6
# Found 590 pixels for color (220, 220, 0) with train_id 7
# Found 17958 pixels for color (107, 142, 35) with train_id 8
# Found 9045 pixels for color (152, 251, 152) with train_id 9
# Found 152010 pixels for color (70, 130, 180) with train_id 10
# Found 307 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 9865 pixels for color (0, 0, 142) with train_id 13
# Found 3790 pixels for color (0, 0, 70) with train_id 14
# Found 0 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18
# Found 185893 pixels for color (128, 64, 128) with train_id 0
# Found 8370 pixels for color (244, 35, 232) with train_id 1
# Found 130998 pixels for color (70, 70, 70) with train_id 2
# Found 91 pixels for color (102, 102, 156) with train_id 3
# Found 36 pixels for color (190, 153, 153) with train_id 4
# Found 4782 pixels for color (153, 153, 153) with train_id 5
# Found 2350 pixels for color (250, 170, 30) with train_id 6
# Found 704 pixels for color (220, 220, 0) with train_id 7
# Found 34802 pixels for color (107, 142, 35) with train_id 8
# Found 11 pixels for color (152, 251, 152) with train_id 9
# Found 48569 pixels for color (70, 130, 180) with train_id 10
# Found 1984 pixels for color (220, 20, 60) with train_id 11
# Found 0 pixels for color (255, 0, 0) with train_id 12
# Found 4256 pixels for color (0, 0, 142) with train_id 13
# Found 5200 pixels for color (0, 0, 70) with train_id 14
# Found 1 pixels for color (0, 60, 100) with train_id 15
# Found 0 pixels for color (0, 80, 100) with train_id 16
# Found 0 pixels for color (0, 0, 230) with train_id 17
# Found 0 pixels for color (119, 11, 32) with train_id 18

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.imshow(mask, cmap='nipy_spectral', vmin=0, vmax=18)
plt.title(f"TrainId Mask for {filename}")
plt.axis('off')
plt.colorbar(label='trainId')
plt.show()
