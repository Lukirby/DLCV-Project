# %% [markdown]
# # Task
# Resize all images in the "images" folder to 957x526 and save them to the "resized_images" folder, maintaining the original filenames.

# %% [markdown]
# ## Create output directory
#
# ### Subtask:
# Create the `resized_images` directory if it doesn't exist.

# %% [markdown]
# **Reasoning**:
# Check if the target directory exists and create it if necessary.

# %%
import os
in_dir = "folder_path"
out_dir  = "target_folder_path"

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %% [markdown]
# ## List image files
#
# ### Subtask:
# Get a list of all image files in the `images` directory.

# %% [markdown]
# **Reasoning**:
# List all files in the `images` directory and filter for image file extensions.

# %%
import os

image_files = [f for f in os.listdir(in_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# %% [markdown]
# ## Resize and save images
#
# ### Subtask:
# Iterate through the list of image files, resize each image to 957x526, and save it to the `resized_images` directory with the same filename.

# %% [markdown]
# **Reasoning**:
# Iterate through the list of image files, resize each image to 957x526, and save it to the `resized_images` directory with the same filename.

# %%
from PIL import Image

target_size = (957, 526)

for filename in image_files:
    input_path = os.path.join(in_dir, filename)
    output_path = os.path.join(out_dir, filename)
    print(f"Resizing {input_path} to {target_size} and saving to {output_path}")
    with Image.open(input_path) as img:
        resized_img = img.resize(target_size, resample=Image.Resampling.NEAREST)
        resized_img.save(output_path)
# Out:
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03836.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03836.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04181.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04181.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03188.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03188.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03822.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03822.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04195.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04195.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04803.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04803.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04817.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04817.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04142.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04142.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02533.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02533.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04624.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04624.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04630.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04630.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04156.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04156.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03639.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03639.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02527.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02527.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03611.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03611.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03177.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03177.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04618.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04618.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03163.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03163.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03605.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03605.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04383.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04383.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04397.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04397.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02916.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02916.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02902.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02902.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04426.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04426.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03349.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03349.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02731.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02731.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04340.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04340.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02725.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02725.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04354.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04354.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04432.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04432.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03375.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03375.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03413.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03413.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02719.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02719.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03407.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03407.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04368.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04368.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03361.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03361.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04591.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04591.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02686.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02686.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03598.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03598.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02692.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02692.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04585.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04585.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02862.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02862.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02876.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02876.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04552.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04552.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04234.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04234.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02645.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02645.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04220.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04220.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02889.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02889.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02651.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02651.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03229.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03229.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04546.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04546.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03201.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03201.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04208.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04208.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03567.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03567.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02679.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02679.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03573.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03573.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03215.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03215.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03942.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03942.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04793.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04793.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04787.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04787.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03956.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03956.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04977.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04977.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04963.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04963.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03981.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03981.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03759.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03759.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04036.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04036.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04750.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04750.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04988.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04988.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04744.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04744.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03995.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03995.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04022.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04022.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03765.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03765.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03003.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03003.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04778.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04778.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03017.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03017.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03771.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03771.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03016.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03016.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04779.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04779.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03770.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03770.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03764.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03764.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03002.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03002.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04745.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04745.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04023.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04023.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03994.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03994.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04037.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04037.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03758.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03758.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03980.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03980.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04989.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04989.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04751.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04751.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04962.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04962.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04976.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04976.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04786.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04786.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03957.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03957.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03943.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03943.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04792.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04792.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03572.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03572.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03214.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03214.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03200.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03200.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02678.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02678.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03566.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03566.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04209.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04209.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02650.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02650.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/02888.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/02888.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04221.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04221.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04547.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/04547.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/03228.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/03228.png
# Resizing /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/syn_labels/04553.png to (957, 526) and saving to /Users/francescazenatti/Python_projects/Segmentation+adapt/dataset_progetto_cvdl/02_syn_resized_labels/